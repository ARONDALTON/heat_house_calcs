# %%
import thermo as th

# %%
>>> from thermo.chemical import Chemical
>>> tol = Chemical('toluene')
>>> tol.Tm, tol.Tb, tol.Tc
# Out:
# (179.2, 383.75, 591.75)

# %%
tol.rho, tol.Cp, tol.k, tol.mu
# Out:
# (864.0188991629486,
#  1706.0746129119086,
#  0.12971616855302529,
#  0.0005550438687588128)

# %%
>>> tol.calculate(T=310, P=101325)
>>> tol.rho, tol.Cp, tol.k, tol.mu
# Out:
# (853.0981230303128,
#  1743.2804975110885,
#  0.12690086693398103,
#  0.00048716143133897485)

# %%
tol.calculate(310, 2E6)

# %%
 tol.rho, tol.Cp, tol.k, tol.mu
# Out:
# (855.2246059628734,
#  1743.2804975110885,
#  0.1276607199332653,
#  0.0004983961650305411)

# %%
Chemical('toluene').VaporPressure.solve_prop(2E5)
# Out:
# 409.5909115602903

# %%
Chemical('toluene').SurfaceTension.plot_T_dependent_property()
# Out:
# C:\Users\aron\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py:2628: RuntimeWarning: divide by zero encountered in true_divide
#   tmp = dot(tmp,np.diag(1.0/s))
# C:\Users\aron\Anaconda3\lib\site-packages\matplotlib\scale.py:93: RuntimeWarning: invalid value encountered in less_equal
#   mask = a <= 0.0

# %%
from thermo.chemical import Mixture
>>> vodka = Mixture(['water', 'ethanol'], Vfls=[.6, .4], T=300, P=1E5)
>>> vodka.Prl,vodka.Prg
# Out:
# (35.02070654113623, 0.9935609103164759)

# %%
air = Mixture('air', T=300, P=1e5)
>>> air.Cp
# Out:
# 1004.8329123211819

# %%
air.Chemicals
# Out:
# [<Chemical [nitrogen], T=300.00 K, P=100000 Pa>,
#  <Chemical [argon], T=300.00 K, P=100000 Pa>,
#  <Chemical [oxygen], T=300.00 K, P=100000 Pa>]

# %%
Chemical('cubane').draw_3d()
# Out:
# 'py3Dmol, RDKit, and IPython are required for this feature.'

# %%
import RDKit
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-3b74f90bc59e> in <module>()
# ----> 1 import RDKit
#
# ImportError: No module named 'RDKit'

# %%
import sympy as sy
