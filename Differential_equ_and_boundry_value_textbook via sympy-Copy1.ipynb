# %% [markdown]
# from section 2.1 of text

# %%
from sympy import *
init_printing()

# %%
t,m ,C ,g,k ,v =symbols('t m C g k v')

# %%
v = Function("v")

# %%
type(v)
# Out:
# sympy.core.function.UndefinedFunction

# %%
Fd,ro,A,Cd=symbols('Fd ro A Cd')

# %%
drag=(Eq(Fd,1/2*ro*A*Cd*v(t)**2))
drag
# Out:
#                   2
# Fd = 0.5⋅A⋅Cd⋅ro⋅v (t)

# %%
# Fd=1/2*ro*A*Cd*v**2
# Fd
solve(drag,v(t))
# Out:
# ⎡                     _________                      _________⎤
# ⎢                    ╱    Fd                        ╱    Fd   ⎥
# ⎢-1.4142135623731⋅  ╱  ─────── , 1.4142135623731⋅  ╱  ─────── ⎥
# ⎣                 ╲╱   A⋅Cd⋅ro                   ╲╱   A⋅Cd⋅ro ⎦

# %%
equ=Eq(v(t).diff(t) *m , m*g-Fd).subs({Fd:drag.rhs})#k*v(t))
#  9*f(x) + Derivative(f(x), x, x) == 1
equ
# Out:
#   d                         2
# m⋅──(v(t)) = - 0.5⋅A⋅Cd⋅ro⋅v (t) + g⋅m
#   dt

# %%
sol=dsolve(equ, v(t))
#  f(x) == C1*cos(3*x) + C2*sin(3*x) + 1/9
sol
# Out:
#       _____________ ⎛                     ⎛                          _________
#      ╱      1       ⎜                     ⎜                         ╱      1
# m⋅  ╱  ─────────── ⋅⎜0.707106781186548⋅log⎜- 1.4142135623731⋅g⋅m⋅  ╱  ────────
#   ╲╱   A⋅Cd⋅g⋅m⋅ro  ⎝                     ⎝                      ╲╱   A⋅Cd⋅g⋅m
#
# ____           ⎞                        ⎛                        _____________
#                ⎟                        ⎜                       ╱      1
# ───  + 1.0⋅v(t)⎟ - 0.707106781186548⋅log⎜1.4142135623731⋅g⋅m⋅  ╱  ───────────
# ⋅ro            ⎠                        ⎝                    ╲╱   A⋅Cd⋅g⋅m⋅ro
#
#            ⎞⎞
#            ⎟⎟
#  + 1.0⋅v(t)⎟⎟ = C₁ - t
#            ⎠⎠

# %%
C1= Symbol('C1')

# %%
sol.rhs.subs({t:0})
# Out:
# C1

# %%
C1_t0=solve(sol.subs({t:0}),C1)[0]
C1_t0
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-12-daca5e4f146e> in <module>()
# ----> 1 C1_t0=solve(sol.subs({t:0}),C1)[0]
#       2 C1_t0
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1033             if fi.has(Float):
#    1034                 floats = True
# -> 1035                 f[i] = nsimplify(fi, rational=True)
#    1036
#    1037     # Any embedded piecewise functions need to be brought out to the
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\simplify\simplify.py in nsimplify(expr, constants, tolerance, full, rational)
#    1130     """
#    1131     try:
# -> 1132         return sympify(as_int(expr))
#    1133     except (TypeError, ValueError):
#    1134         pass
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\compatibility.py in as_int(n)
#     400     """
#     401     try:
# --> 402         result = int(n)
#     403         if result != n:
#     404             raise TypeError
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in __int__(self)
#     193         # places) we need to test whether we are off by one.
#     194         from sympy import Dummy
# --> 195         r = self.round(2)
#     196         if not r.is_Number:
#     197             raise TypeError("can't convert complex to int")
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
# ...
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3149         if not x.is_real:
#    3150             i, r = x.as_real_imag()
# -> 3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#    3153             return x
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in round(self, p)
#    3148             return x
#    3149         if not x.is_real:
# -> 3150             i, r = x.as_real_imag()
#    3151             return i.round(p) + S.ImaginaryUnit*r.round(p)
#    3152         if not x:
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\add.py in as_real_imag(self, deep, **hints)
#     775         re_part, im_part = [], []
#     776         for term in sargs:
# --> 777             re, im = term.as_real_imag(deep=deep)
#     778             re_part.append(re)
#     779             im_part.append(im)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\mul.py in as_real_imag(self, deep, **hints)
#     760                 return (r, i)
#     761             return (-imco*i, imco*r)
# --> 762         addre, addim = expand_mul(addterms, deep=False).as_real_imag()
#     763         if imco is S.Zero:
#     764             return (r*addre - i*addim, i*addre + r*addim)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\add.py in as_real_imag(self, deep, **hints)
#     775         re_part, im_part = [], []
#     776         for term in sargs:
# --> 777             re, im = term.as_real_imag(deep=deep)
#     778             re_part.append(re)
#     779             im_part.append(im)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\mul.py in as_real_imag(self, deep, **hints)
#     750             imco = S.Zero
#     751         reco = self.func(*(coeffr + coeffi))
# --> 752         r, i = (reco*re(m), reco*im(m))
#     753         if addterms == 1:
#     754             if m == 1:
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\decorators.py in __sympifyit_wrapper(a, b)
#      75                 if not hasattr(b, '_op_priority'):
#      76                     b = sympify(b, strict=True)
# ---> 77                 return func(a, b)
#      78             except SympifyError:
#      79                 return retval
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\numbers.py in __mul__(self, other)
#     943             rhs, prec = other._as_mpf_op(self._prec)
#     944             return Float._new(mlib.mpf_mul(self._mpf_, rhs, prec, rnd), prec)
# --> 945         return Number.__mul__(self, other)
#     946
#     947     @_sympifyit('other', NotImplemented)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\decorators.py in __sympifyit_wrapper(a, b)
#      75                 if not hasattr(b, '_op_priority'):
#      76                     b = sympify(b, strict=True)
# ---> 77                 return func(a, b)
#      78             except SympifyError:
#      79                 return retval
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\numbers.py in __mul__(self, other)
#     473         elif isinstance(other, Tuple):
#     474             return NotImplemented
# --> 475         return AtomicExpr.__mul__(self, other)
#     476
#     477     @_sympifyit('other', NotImplemented)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\decorators.py in __sympifyit_wrapper(a, b)
#      75                 if not hasattr(b, '_op_priority'):
#      76                     b = sympify(b, strict=True)
# ---> 77                 return func(a, b)
#      78             except SympifyError:
#      79                 return retval
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     116                     else:
#     117                         return f(self)
# --> 118             return func(self, other)
#     119         return binary_op_wrapper
#     120     return priority_decorator
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in __mul__(self, other)
#     139     @call_highest_priority('__rmul__')
#     140     def __mul__(self, other):
# --> 141         return Mul(self, other)
#     142
#     143     @_sympifyit('other', NotImplemented)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\numbers.py in __hash__(self)
#    1111
#    1112     def __hash__(self):
# -> 1113         return super(Float, self).__hash__()
#    1114
#    1115     def epsilon_eq(self, other, epsilon="1e-15"):
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\numbers.py in __hash__(self)
#     525
#     526     def __hash__(self):
# --> 527         return super(Number, self).__hash__()
#     528
#     529     def is_constant(self, *wrt, **flags):
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
equation=sol.subs({C1:C1_t0})
equation#.simplify(deep=True)

# %%
simp=equation.subs({k:.5,g:9.8,m:40})
simp

# %%
simp.rhs.subs({v(0):10})

# %% [raw]
# plot(equation,t)

# %% [raw]
# solve(sol.rhs.subs({C1:C1_t0}))

# %%
# make a numpy-ready function from the sympy results
from matplotlib import pyplot as plt
# import seaborn as sns
import numpy as np
func = lambdify([t,v(0)], simp.rhs,'numpy')
xvals = np.arange(0,100,1)

# %%
v

# %%
func(10,0)

# %%
vVals=np.arange(0,30,1)
xx,yy=np.meshgrid(xvals,vVals)

# %%
yvals = func(xx,yy)
yvals.shape

# %%
# make figure
fig, ax = plt.subplots(1,1)#,subplot_kw=dict(aspect='equal'))     
ax.contour(xx,yvals, yy)
ax.set_xlabel('t')
ax.set_ylabel('v(t)')
plt.show()

# %%
integrate(1/m+C,(t))

# %%
from sympy import *

m = float(input('Mass:\n> '))
g = 9.8
k = float(input('Drag Coefficient:\n> '))
f = Function('f')
f1 = g * m
t = Symbol('t')
v = Function('v')
equation = dsolve(f1 - k * v(t) - m * Derivative(v(t)), 0)
print(equation)
C1 = Symbol('C1')
C1_ic = solve(equation.rhs.subs({t:0}),C1)[0]
equation = equation.subs({C1:C1_ic})
print(equation,equation.rhs,C1_ic)
plot(equation.rhs,(t,0.0,100.0))

# %%
>>> from sympy import Function, dsolve, Eq, Derivative, sin, cos, symbols
>>> from sympy.abc import x
>>> f = Function('f')
x=Symbol('x')
eq=Eq(Derivative(f(x), x, x) + 9*f(x), f(x))

eq
# Out:
#            2
#           d
# 9⋅f(x) + ───(f(x)) = f(x)
#            2
#          dx

# %%
# plot(eq.lhs,(f(x),0,10))
eq.lhs
# Out:
#            2
#           d
# 9⋅f(x) + ───(f(x))
#            2
#          dx

# %%
>>> eq1=dsolve(eq)
eq1
# Out:
# f(x) = C₁⋅sin(2⋅√2⋅x) + C₂⋅cos(2⋅√2⋅x)

# %%
eq1.rhs.apart()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-52-5cf568f5e255> in <module>()
# ----> 1 eq1.rhs.apart()
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\core\expr.py in apart(self, x, **args)
#    3036         """See the apart function in sympy.polys"""
#    3037         from sympy.polys import apart
# -> 3038         return apart(self, x, **args)
#    3039
#    3040     def ratsimp(self):
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\utilities\decorator.py in threaded_func(expr, *args, **kwargs)
#      35                                       func(expr.rhs, *args, **kwargs))
#      36             else:
# ---> 37                 return func(expr, *args, **kwargs)
#      38
#      39     return threaded_func
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\polys\partfrac.py in apart(f, x, full, **options)
#     124
#     125         raise NotImplementedError(
# --> 126             "multivariate partial fraction decomposition")
#     127
#     128     common, P, Q = P.cancel(Q)
#
# NotImplementedError: multivariate partial fraction decomposition

# %%
plot(eq1.rhs.subs({C1:}))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-914a3262c95f> in <module>()
# ----> 1 plot(eq1)
#
# C:\Users\aron\Anaconda3\lib\site-packages\sympy\plotting\plot.py in plot(*args, **kwargs)
#    1270             if len(free) > 1:
#    1271                 raise ValueError(
# -> 1272                     'The same variable should be used in all '
#    1273                     'univariate expressions being plotted.')
#    1274     x = free.pop() if free else Symbol('x')
#
# ValueError: The same variable should be used in all univariate expressions being plotted.
